# %%
# 匯入 Selenium 的 WebDriver 模組
from selenium import webdriver 

# 啟動新的Chrome 瀏覽器
driver = webdriver.Chrome()

# 載入網頁
url = "https://www.ispan.com.tw/"
driver.get(url)

# 關閉瀏覽器
#driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# 設定 Options (瀏覽器層級設定)
options = Options()
options.add_argument("--start-maximized") #最大化視窗
options.add_argument("--disable-blink-features=AutomationControlled") # 避免被視為機器人
# 設定 User-Agent
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36") 
# options.add_argument("--headless") #無頭模式 (可選)

# 實例化 WebDriver
driver = webdriver.Chrome(options = options)

try:
	driver.get("https://www.ispan.com.tw/")
	print("Page Title:", driver.title)
finally:
	driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

driver = webdriver.Chrome()
#title = iSpan資展國際｜數位人才培育｜課程多元
url = "https://www.ispan.com.tw/"
driver.get(url)
# 驗證網頁標題是否包含特定文字
assert "iSpan資展國際｜數位人才培育｜課程多元" in driver.title
driver.quit()

# %% [markdown]
# ### 透過CSS 選擇器定位元素

# %%
# 匯入 webdriver 模組
from selenium import webdriver 

# 匯入 By 類別，用於定位元素
from selenium.webdriver.common.by import By 

# 匯入 sleep 函數，用於暫停執行
from time import sleep 

# 啟動 Chrome 瀏覽器
driver = webdriver.Chrome() 

# 設定目標網址
url = "https://www.ispan.com.tw/" 

# 前往指定網址
driver.get(url) 
# 驗證網頁標題是否包含特定字串
assert 'iSpan資展國際｜數位人才培育｜課程多元' in driver.title 

# 透過 CSS 選擇器尋找特定連結元素
elem = driver.find_element(By.CSS_SELECTOR, 'a[href="/longterm/"]')

# 點擊該元素
elem.click() 

# 驗證跳轉後的網頁標題
assert '就業養成 | iSpan資展國際' in driver.title 

# 暫停 5 秒
sleep(5) 

# 關閉瀏覽器視窗並結束驅動程序
driver.quit()

# %% [markdown]
# ### 1. `By.LINK_TEXT` (精確比對)
# 比對超連結的完整文字。
# ```python
# element = driver.find_element(By.LINK_TEXT, "完整連結文字")
# ```
#
# ### 2. `By.PARTIAL_LINK_TEXT` (模糊比對)
# 比對超連結的部分文字。
# ```python
# element = driver.find_element(By.PARTIAL_LINK_TEXT, "部分文字")
# ```

# %%
# 匯入 selenium 的 webdriver 模組
from selenium import webdriver

# 匯入 By 模組，用於定位元素
from selenium.webdriver.common.by import By

# 匯入 sleep 函式，用於暫停執行
from time import sleep

# 啟動 Chrome 瀏覽器
driver = webdriver.Chrome()

# 設定目標網址
url = "https://www.ispan.com.tw/"

# 開啟網頁
driver.get(url)

# 驗證網頁標題是否包含特定文字
assert 'iSpan資展國際｜數位人才培育｜課程多元' in driver.title

#<a class="text_item__mb__cpycp" style="display:inline-block" href="/privacypolicy/">服務條款及隱私權保護政策</a>
elem = driver.find_element(By.PARTIAL_LINK_TEXT, '隱私權')

# 點擊該元素
elem.click()

# 暫停 5 秒
sleep(5)

# 關閉瀏覽器並結束視窗
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[2], line 23
#      20 assert 'iSpan資展國際｜數位人才培育｜課程多元' in driver.title
#      22 #<a class="text_item__mb__cpycp" style="display:inline-block" href="/privacypolicy/">服務條款及隱私權保護政策</a>
# ---> 23 elem = driver.find_element(By.PARTIAL_LINK_TEXT, '請隨手關門')
#      25 # 點擊該元素
#      26 elem.click()
#
# File c:\Users\mapd\OneDrive - ispan.com.tw\桌面\2_教學研發\02_Python_Web_Scrapping\2_Code_Examples\.venv_web_scrapping\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\mapd\OneDrive - ispan.com.tw\桌面\2_教學研發\02_Python_Web_Scrapping\2_Code_Examples\.venv_web_scrapping\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\mapd\OneDrive - ispan.com.tw\桌面\2_教學研發\02_Python_Web_Scrapping\2_Code_Examples\.venv_web_scrapping\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"partial link text","selector":"請隨手關門"}
#   (Session info: chrome=144.0.7559.97); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff75059a535
# 	0x7ff75059a590
# 	0x7ff7503410bd
# 	0x7ff75039c48e
# 	0x7ff75039c79c
# 	0x7ff7503ed3a7
# 	0x7ff7503e9ef5
# 	0x7ff75038cc9c
# 	0x7ff75038dbe3
# 	0x7ff750877b60
# 	0x7ff750871f5d
# 	0x7ff75089311a
# 	0x7ff7505b60a5
# 	0x7ff7505be73c
# 	0x7ff7505a3844
# 	0x7ff7505a39f6
# 	0x7ff750589a07
# 	0x7ff9c14b7374
# 	0x7ff9c19bcc91

# %%
driver.quit()
