# %% [markdown]
# ### ✅ 起手式_引入套件與實例化物件 已帶過，請執行
# 執行此儲存格以確認 `demoHTML_str` 已成功載入並經 `BeautifulSoup` 解析。
# 若無報錯且環境變數已就緒，即可開始針對 DOM 節點進行資料提取操作。

# %%
from pathlib import Path
from bs4 import BeautifulSoup as bs
import requests as req
from pprint import pprint
import json

html_path = Path("data4BS") / "2025 人工智慧基礎名詞大百科.html"
demoHTML_str = html_path.read_text(encoding="utf-8")

soup = bs(demoHTML_str, 'lxml')

# %% [markdown]
# ### 🌳 BeautifulSoup 物件結構與屬性操作
# `soup` 物件將 HTML 文件轉化為複雜的 Python 樹狀結構 (DOM Tree)。
# 透過直觀的屬性存取，我們能快速獲取特定標籤 (`Tag`)、名稱 (`.name`)、屬性 (`.attrs`) 及內文 (`.text`)。
# <br><br>
# 以下示範如何利用這些核心屬性進行資料定位與提取。

# %%
#取得標籤為<title>的元素


# 使用Dot Notation存取<title>標籤
# 我們預期程式會給我第一個找到的 <title> 元素

# %%
# 取得第一個標籤為<title>元素(return:物件)
# 並複習屬性的概念(物件導向)，取得標籤名稱與文字內容
'''
標籤為<title>元素(soup.title)這個Python物件有多個屬性
name屬性會回傳標籤名稱
text屬性會回傳標籤內的文字內容
'''

# %%
#取出標籤內的class屬性值

#爬蟲常用 取得href屬性值


#爬蟲常用 取得圖片標籤的src屬性值

# %%
# 載入內鍵的作業系統介面模組，用於跨平台的路徑與檔案操作


# 利用 os.path.basename() 從完整的URL字串中，萃取出最後一層的檔案名稱


# 利用 os.path.join() 將當前目錄 ('.') 與取得的檔案名稱結合，生成符合當前作業系統規範的安全路徑


# 透過 HTTP GET 方法向伺服器請求資源，並將伺服器回傳的 Response 物件指派給變數 res


# 使用 Context Manager (with語法) 以二進位寫入模式('wb')開啟或建立檔案

    # 存取 Response 物件的 content 屬性 (二進位 Payload)，並將其寫入本機檔案中

# %%
#.get() 方法取得屬性值
#.get('src') 就像是『禮貌詢問』。
# 你問它有沒有連結？如果有就給你，如果沒有，它會優雅地回傳 None，讓程式繼續跑下去。
# 在爬取大量網頁時，我們通常喜歡當個有禮貌的爬蟲。
